# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
audi=pd.read_csv('/home/mehnaz/Downloads/audi.csv')

# %%
audi
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
audi.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %% [markdown]
# # EDA performing

# %%
audi.head()

# %%
print('shape',audi.shape)
#10668 rows and 9 columns
# Out:
# shape (10668, 9)

# %%
print('Null values',audi.isnull().sum())
#no null values
# Out:
# Null values model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# mpg             0
# engineSize      0
# dtype: int64

# %%
print('Columns Datatype \n\n',audi.dtypes)
# Out:
# Columns Datatype
#
#  model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %% [markdown]
# # Summary statistics

# %%
print('Summary statistics')
audi.describe()
# Out:
# Summary statistics
#                year          price        mileage           tax           mpg
# count  10668.000000   10668.000000   10668.000000  10668.000000  10668.000000  \
# mean    2017.100675   22896.685039   24827.244001    126.011436     50.770022
# std        2.167494   11714.841888   23505.257205     67.170294     12.949782
# min     1997.000000    1490.000000       1.000000      0.000000     18.900000
# 25%     2016.000000   15130.750000    5968.750000    125.000000     40.900000
# 50%     2017.000000   20200.000000   19000.000000    145.000000     49.600000
# 75%     2019.000000   27990.000000   36464.500000    145.000000     58.900000
# max     2020.000000  145000.000000  323000.000000    580.000000    188.300000
#
#          engineSize
# count  10668.000000
# mean       1.930709
# std        0.602957
# min        0.000000
# 25%        1.500000
# 50%        2.000000
# 75%        2.000000
# max        6.300000

# %% [markdown]
# # some visualization

# %%
#histogram: shows the distribution of the data 
plt.figure(figsize=(8,5))
sns.histplot(audi['price'])
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of car price')
plt.show()

# %%
#scatter plot: distance between the two variables
plt.figure(figsize=(8,5))
sns.scatterplot(data=audi,x=audi['mileage'],y=audi['price'])
plt.title('price VS mileage')
plt.show()

# %%
#Boxplot: show the visual summary of values in dataset. shows the mean,medium,mode,max,min,1st quartile,2nd qurtile,
#3rd quartile , IQR value , upper limit ,lower limit and outliers(if any).

plt.figure(figsize=(8,5))
sns.boxplot(data=audi,y=audi['price'],x=audi['fuelType'])
plt.title('price VS fuelType')
plt.show()

# %%
audi.head(2)
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=audi,x=audi['model'])
plt.xticks(rotation=90)
plt.title('Frequency of each model')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=audi,x=audi['transmission'])
plt.title('Count of Transmission')
plt.show()

# %%
sns.pairplot(data=audi)
plt.show()

# %%
#deleting the duplicated values
data=audi.drop_duplicates()

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.head(2)
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0

# %% [markdown]
# # feature engenering

# %%
#adding new  car age feature in data-set.

# %%
from datetime import datetime
current_year=datetime.now().year
current_year
data['car_age']=current_year-data['year']
# Out:
# /tmp/ipykernel_3565/2466643349.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['car_age']=current_year-data['year']

# %%
data.head(2)
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4  \
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
#
#    car_age
# 0        6
# 1        7

# %% [markdown]
# # Visualization

# %%
#price distribution amoung car's model 
sns.boxplot(data=data,y=data['price'],x=data['model'])

plt.xticks(rotation=90)
plt.title('Distribution of model and price')
plt.show()

# %%
#price distribution in each year
sns.boxplot(data=data,y=data['price'],x=data['year'])
plt.xticks(rotation=90)
plt.xlabel('distribution of price and year')
plt.show()

# %%
data.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4  \
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
#
#    car_age
# 0        6
# 1        7
# 2        7
# 3        6
# 4        4

# %%
data['year']=audi['year']
# Out:
# /tmp/ipykernel_3565/2405019962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year']=audi['year']

# %%
data['year']
# Out:
# 0        2017
# 1        2016
# 2        2016
# 3        2017
# 4        2019
#          ...
# 10663    2020
# 10664    2020
# 10665    2020
# 10666    2017
# 10667    2016
# Name: year, Length: 10565, dtype: int64

# %%
'''Price Variation with Mileage and Age: Explore how the price of used cars changes based on their mileage and age. 
You can use scatter plots or line plots to visualize these relationships.'''

plt.figure(figsize=(8,5))
plt.scatter(x=data['mileage'],y=data['price'])
plt.title('Price Variation with Mileage')
plt.xlabel('Mileage')
plt.show()


plt.figure(figsize=(8,5))
plt.scatter(x=data['car_age'],y=data['price'])
plt.title('Price Variation with Age')
plt.xlabel('Car_age')
plt.show()

# %%
#Price Comparison Across Fuel Types:

# %%
data['fuelType'].value_counts()
# Out:
# fuelType
# Diesel    5537
# Petrol    5000
# Hybrid      28
# Name: count, dtype: int64

# %%
sns.violinplot(x=data['fuelType'],y=data['price'])

# %%
#Fuel Efficiency Analysis

# %%
price_by_fuel_type = data.groupby('fuelType')['price'].mean()

# %%
price_by_fuel_type
# Out:
# fuelType
# Diesel    23198.206249
# Hybrid    30191.750000
# Petrol    22431.641800
# Name: price, dtype: float64

# %%
#visualization
plt.figure(figsize=((8,5)))
sns.barplot(x=price_by_fuel_type.index,y=price_by_fuel_type.values)
plt.title('Fuel Efficiency Analysis based on price')
plt.xlabel('FuelType')
plt.ylabel('Price')
plt.show()

# %%
#Point 7: Fuel Efficiency Analysis

data['fuel_effency']=data['mpg']
# Out:
# /tmp/ipykernel_3565/224432745.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['fuel_effency']=data['mpg']

# %%
data.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4  \
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
#
#    car_age  fuel_effency
# 0        6          55.4
# 1        7          64.2
# 2        7          55.4
# 3        6          67.3
# 4        4          49.6

# %%
plt.figure(figsize=(8,5))
plt.hist(x=data['fuel_effency'])
plt.title('Distribution of fuel Effency')
plt.xlabel('fuel effency')
plt.show()

# %%
'''Hypothesis Testing: You can use hypothesis testing to make inferences about the population based on sample data. 
For example, you can test whether there is a significant difference in the average price 
of Audi cars based on fuel type or whether the average mileage is different for automatic and manual transmission
cars.
'''

# %%
#ho=there is a significant difference in the average price of cars 
#ha=here is no significant difference in the average price of cars

# %% [markdown]
# # one sample t test

# %%
group1=data['price']
#populaton mean
pop_mean=data['price'].mean()
pop_mean
# Out:
# 22853.95608140085

# %%
#sample mean

from random import sample
from scipy.stats import ttest_1samp

sample1=group1.sample(20)
#performing t_test
_,pvalue=sts.ttest_1samp(sample1,pop_mean)
pvalue
# Out:
# 0.5278969373508218

# %%
if pvalue < 0.05:
    print('Reject the Null Hypothesis')
    
else:
    print('fail to reject')
# Out:
# Reject the Null Hypothesis

# %% [markdown]
# # two samplet test

# %%
#ho="There is significant difference in the average price of Diesel and Petrol cars."
#ha="There is no significant difference in the average price of Diesel and Petrol cars."

# %%
data['fuelType'].value_counts()
# Out:
# fuelType
# Diesel    5537
# Petrol    5000
# Hybrid      28
# Name: count, dtype: int64

# %%
one=data[data['fuelType']=='Diesel']['price']
two=data[data['fuelType']=='Petrol']['price']

# %%
from scipy.stats import ttest_ind
_,pvalue=ttest_ind(one,two,equal_var=False)
print(pvalue)
# Out:
# 0.0007421253993640573

# %%
if pvalue < 0.05:
    print('The average price of Diesel and Petrol cars is significantly different.')
else:
    print('"There is no significant difference in the average price of Diesel and Petrol cars.')
# Out:
# The average price of Diesel and Petrol cars is significantly different.

# %% [markdown]
# # anova test

# %%
#To perform an ANOVA test on the Audi dataset to compare the average price of used cars based on different 
#fuel types

# %%
from statsmodels.formula.api import ols
import statsmodels.api as sm

formula = 'price ~ C(fuelType)'
model = ols(formula, data=data).fit()
anova_table = sm.stats.anova_lm(model, typ=2)

# %%
print(anova_table)
# Out:
#                    sum_sq       df          F    PR(>F)
# C(fuelType)  3.055537e+09      2.0  11.137996  0.000015
# Residual     1.448761e+12  10562.0        NaN       NaN

# %%
data.head()
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4  \
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
#
#    car_age  fuel_effency
# 0        6          55.4
# 1        7          64.2
# 2        7          55.4
# 3        6          67.3
# 4        4          49.6

# %%
numeric_column=['price','mileage','tax','mpg','engineSize','car_age','fuel_effency']

# %%
correlation_matrix =data[numeric_column].corr()

# %%
correlation_matrix
# Out:
#                price   mileage       tax       mpg  engineSize
# price       1.000000 -0.534739  0.355614 -0.598854    0.594788
# mileage    -0.534739  1.000000 -0.162657  0.390701    0.068858
# tax         0.355614 -0.162657  1.000000 -0.635786    0.396130
# mpg        -0.598854  0.390701 -0.635786  1.000000   -0.370247
# engineSize  0.594788  0.068858  0.396130 -0.370247    1.000000

# %%
plt.figure(figsize=(8,5))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.5)
plt.show()
